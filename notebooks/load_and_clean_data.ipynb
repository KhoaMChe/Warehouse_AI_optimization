# %% [markdown]
# # Warehouse Optimizatiom
# # Notebook — Data Cleaning
# ## 1. Load Warehouse Data

# %%
import pandas as pd 
import numpy as np

# %%
sanpham = pd.read_csv("../data/raw/dm_san_pham.csv", encoding="utf-8")
vitri = pd.read_csv("../data/raw/dm_vi_tri.csv", encoding="utf-8")
nhapkho = pd.read_csv("../data/raw/xnk_nhap_kho_receive.csv")
tonkho = pd.read_csv("../data/raw/xnk_ton_kho.csv", encoding="utf-8")
xuatkho = pd.read_csv("../data/raw/xnk_xuat_kho_actual.csv", encoding="utf-8")
pick = pd.read_csv("../data/raw/xnk_xuat_kho_pick_list.csv", encoding="utf-8")
phieupick = pd.read_csv("../data/raw/xnk_xuat_kho_phieu_pick.csv", encoding="utf-8")
cham = pd.read_csv("../data/raw/log_replenishment.csv")
# Out:
# C:\Users\anhkh\AppData\Local\Temp\ipykernel_13420\3694957732.py:1: DtypeWarning: Columns (0,1,3,4,6,7,8,10,11,12,13,14,15,16,17,18,20,21,22,23,24,25,26,27,28,30,31,32,33,34,35,36,37,38,40,41,43,44,45,48,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   sanpham = pd.read_csv("../data/raw/dm_san_pham.csv", encoding="utf-8")
# C:\Users\anhkh\AppData\Local\Temp\ipykernel_13420\3694957732.py:3: DtypeWarning: Columns (5,6,7,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   nhapkho = pd.read_csv("../data/raw/xnk_nhap_kho_receive.csv")
# C:\Users\anhkh\AppData\Local\Temp\ipykernel_13420\3694957732.py:4: DtypeWarning: Columns (8,9,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   tonkho = pd.read_csv("../data/raw/xnk_ton_kho.csv", encoding="utf-8")
# ...

# %%
print(sanpham.head())
print(vitri.head())
print(nhapkho.head())
print(tonkho.head())
print(xuatkho.head())
print(pick.head())
print(phieupick.head())
print(cham.head())
# Out:
#     auto_id chu_hang_id  nhom_nganh_hang_id nganh_hang_id loai_san_pham_id  \
# 0  12504073    12473661                 0.0      12501018         12500320
# 1  20003159    12473661                 0.0      12501018         12500320
# 2  12504099    12473661                 0.0      12501018         12500320
# 3  12504065    12473661                 0.0      12501018         12500320
# 4  12504075    12473661                 0.0      12501018         12500320
#
#    don_vi_tinh_id don_vi_tinh_thung_id ma_san_pham ma_sp_ncc ten_san_pham  \
# 0      12499665.0                    0    40000001       NaN    SP0000001
# 1      12499665.0             12499662    40000002       NaN    SP0000002
# 2      12499665.0                    0    40000003       NaN    SP0000003
# 3      12499665.0                    0    40000004       NaN    SP0000004
# 4      12499665.0                    0    40000005       NaN    SP0000005
#
# ...

# %% [markdown]
# # 2. Clean Warehouse Data

# %% [markdown]
# ## Phiếu Pick

# %%
print(f"Shape: {phieupick.shape}")
print(f"info: {phieupick.info()}")
# Out:
# Shape: (206274, 34)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206274 entries, 0 to 206273
# Data columns (total 34 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   auto_id                     206274 non-null  int64
#  1   chu_hang_id                 206274 non-null  int64
#  2   kho_id                      206274 non-null  int64
#  3   xuat_kho_id                 206274 non-null  int64
#  4   master_do_id                206274 non-null  int64
#  5   loai_hinh_pick_id           206274 non-null  int64
#  6   trang_thai_pick_id          206274 non-null  int64
#  7   so_phieu_pick               206274 non-null  object
#  8   tong_so_kien_pick           206274 non-null  float64
#  9   tong_sl_pick_chan           206274 non-null  float64
#  10  tong_sl_pick_le             206274 non-null  float64
#  11  tong_sl_pallet_pick         206274 non-null  float64
# ...

# %%
print(f"\nMissing values:\n{phieupick.isnull().sum().sort_values(ascending=False).head(50)}")
# Out:
# Missing values:
# so_vc_pick                    206274
# ghi_chu                       206274
# nv_giao_phieu                 146824
# ngay_gio_giao_phieu           146824
# nv_pick_chi_dinh              137854
# phieu_pick_type_id            113114
# ngay_gio_kt_pick               47202
# ngay_gio_bd_pick               45067
# nv_pick                        45007
# last_updated_by_function           0
# last_updated_by                    0
# last_updated                       0
# chu_hang_id                        0
# created_by                         0
# created                            0
# deleted                            0
# created_by_function                0
# auto_id                            0
# tong_sl_vat_chua                   0
# tong_sl_pallet_picked_xong         0
# tong_sl_picked_le_xong             0
# tong_sl_picked_chan_xong           0
# tong_so_kien_picked_xong           0
# tong_sl_pallet_pick                0
# tong_sl_pick_le                    0
# ...

# %% [markdown]
# ## Xuất kho phiếu pick

# %%
print(f"Shape: {pick.shape}")
print(f"info: {pick.info()}")
# Out:
# Shape: (2796475, 38)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2796475 entries, 0 to 2796474
# Data columns (total 38 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   auto_id                     int64
#  1   chu_hang_id                 int64
#  2   kho_id                      int64
#  3   xuat_kho_id                 int64
#  4   vi_tri_id                   int64
#  5   san_pham_id                 int64
#  6   so_lpn                      object
#  7   so_po                       object
#  8   so_lot                      object
#  9   so_batch                    object
#  10  so_serial                   float64
#  11  ngay_san_xuat               object
#  12  ngay_het_han                object
#  13  ngay_nhap_kho               object
#  14  so_kien_pick                float64
#  15  sl_pick_chan                float64
#  16  sl_pick_le                  float64
#  17  sl_pick_all_special         float64
# ...

# %%
print(f"\nMissing values:\n{pick.isnull().sum().sort_values(ascending=False).head(50)}")
# Out:
# Missing values:
# case_no                       2796475
# so_serial                     2796475
# so_lot                        2796175
# so_vc_level_2                 2790947
# so_batch                      2788275
# ngay_nhap_kho                 2457689
# so_vc_level_1                 2254449
# xk_actual_ref_id              1569392
# ton_kho_ref_id                1569392
# so_lpn                        1173523
# ngay_het_han                   471484
# phieu_pick_id                  338946
# ngay_san_xuat                  268647
# so_po                          186277
# nw                                  0
# last_updated_by_function            0
# last_updated_by                     0
# last_updated                        0
# created_by_function                 0
# created_by                          0
# created                             0
# deleted                             0
# cbm                                 0
# auto_id                             0
# ...

# %%
#drop những data thừa và missing quá nhiều
drop_colums_pick = ["deleted",
    "created",
    "created_by",
    "created_by_function",
    "last_updated",
    "last_updated_by",
    "last_updated_by_function",
    "so_serial", "case_no"]

pick = pick.drop(columns= drop_colums_pick)

# %%
# Xóa dòng trùng
pick = pick.drop_duplicates()

# %%
#tạo file csv clean
#pick.to_csv("../data/clean/xnk_nhap_kho_picklist_clean.csv", index=False)

# %% [markdown]
# ## Nhập Kho

# %%
print(f"Shape: {nhapkho.shape}")
print(f"info: {nhapkho.info()}")
# Out:
# Shape: (310380, 31)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310380 entries, 0 to 310379
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   auto_id                   310380 non-null  int64
#  1   nhap_kho_id               310380 non-null  int64
#  2   san_pham_id               310380 non-null  int64
#  3   nhap_kho_raw_ref_id       310380 non-null  int64
#  4   so_lpn                    307826 non-null  object
#  5   so_po                     216681 non-null  object
#  6   so_batch                  4001 non-null    object
#  7   so_lot                    28 non-null      object
#  8   so_serial                 0 non-null       float64
#  9   ngay_san_xuat             145931 non-null  object
#  10  ngay_het_han              135365 non-null  object
#  11  line_item                 310380 non-null  int64
#  12  ngay_nhap_kho_root        310380 non-null  object
# ...

# %%
print(f"\nMissing values:\n{nhapkho.isnull().sum().sort_values(ascending=False).head(50)}")
# Out:
# Missing values:
# so_serial                   310380
# ghi_chu                     310365
# so_lot                      310352
# so_batch                    306379
# ngay_het_han                175015
# ngay_san_xuat               164449
# so_po                        93699
# so_lpn                        2554
# created                          0
# cbm                              0
# trang_thai_lo_hang_rc_id         0
# deleted                          0
# auto_id                          0
# created_by                       0
# created_by_function              0
# gw                               0
# last_updated                     0
# last_updated_by                  0
# nw                               0
# sl_nhap_chan                     0
# don_gia                          0
# sl_nhap_all_special              0
# sl_nhap_le                       0
# nhap_kho_id                      0
# so_kien_nhap                     0
# ma_key_lo_hang                   0
# ...

# %%
#drop những cột không cần thiết và missing value quá nhiều
drop_colums_nhap = ["deleted",
    "created",
    "created_by",
    "created_by_function",
    "last_updated",
    "last_updated_by",
    "last_updated_by_function",
    "so_serial", "ghi_chu", "so_lot", "so_batch"]

nhapkho = nhapkho.drop(columns= drop_colums_nhap)

# %%
# Xóa dòng trùng
nhapkho = nhapkho.drop_duplicates()

# %%
#tạo file csv clean
# nhapkho.to_csv("../data/clean/xnk_nhap_kho_clean.csv", index=False)

# %% [markdown]
# ## Tồn Kho

# %%
print(f"Shape: {tonkho.shape}")
print(f"info: {tonkho.info()}")
# Out:
# Shape: (692652, 45)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692652 entries, 0 to 692651
# Data columns (total 45 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   auto_id                   692652 non-null  int64
#  1   chu_hang_id               692652 non-null  int64
#  2   kho_id                    692652 non-null  int64
#  3   vi_tri_id                 692652 non-null  int64
#  4   so_lpn                    688173 non-null  object
#  5   nhap_kho_id               692652 non-null  int64
#  6   san_pham_id               692652 non-null  int64
#  7   so_po                     573337 non-null  object
#  8   so_batch                  12258 non-null   object
#  9   so_lot                    231 non-null     object
#  10  so_serial                 0 non-null       float64
#  11  ngay_san_xuat             457737 non-null  object
#  12  ngay_het_han              419630 non-null  object
# ...

# %%
print(f"\nMissing values:\n{tonkho.isnull().sum().sort_values(ascending=False).head(50)}")
# Out:
# Missing values:
# so_serial                   692652
# so_lot                      692421
# ghi_chu                     692208
# so_batch                    680394
# clone_id                    647776
# ngay_gio_putaway            447449
# nv_putaway                  447449
# ngay_het_han                273022
# ngay_san_xuat               234915
# so_po                       119315
# sl_dc_all_special            47484
# sl_dc_le                     47484
# sl_dc_chan                   47484
# so_kien_dc                   47484
# so_kien_tach                 47474
# sl_xuat_all_special          29327
# sl_xuat_chan                 29327
# so_kien_xuat                 29327
# sl_xuat_le                   29327
# so_lpn                        4479
# trang_thai_lo_hang_id            0
# nw                               0
# deleted                          0
# cbm                              0
# created                          0
# created_by                       0
# ...

# %%
#drop những data thừa không cần thiết và missing value quá nhiều
drop_colums_ton = ["deleted",
    "created",
    "created_by",
    "created_by_function",
    "last_updated",
    "last_updated_by",
    "last_updated_by_function",
    "so_serial", "ghi_chu", "so_lot", "so_batch","ngay_gio_putaway","nv_putaway"]

tonkho = tonkho.drop(columns= drop_colums_ton)

# %%
# Xóa dòng trùng
tonkho = tonkho.drop_duplicates()

# %%
#tạo file csv clean
# tonkho.to_csv("../data/clean/xnk_ton_kho_clean.csv", index=False)

# %% [markdown]
# ## Châm hàng

# %%
print(f"Shape: {cham.shape}")
print(f"info: {cham.info()}")
# Out:
# Shape: (134887, 28)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134887 entries, 0 to 134886
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   auto_id                       134887 non-null  int64
#  1   chu_hang_id                   134887 non-null  int64
#  2   kho_id                        134887 non-null  int64
#  3   san_pham_id                   134887 non-null  int64
#  4   xuat_kho_id                   134887 non-null  int64
#  5   ton_kho_id                    134887 non-null  int64
#  6   so_lpn                        134776 non-null  object
#  7   ma_so_vi_tri_cu               134887 non-null  object
#  8   ma_so_vi_tri_moi              134887 non-null  object
#  9   so_kien_repleshniment         134887 non-null  float64
#  10  sl_repleshniment_chan         134887 non-null  float64
#  11  sl_repleshniment_le           134887 non-null  float64
# ...

# %%
print(f"\nMissing values:\n{cham.isnull().sum().sort_values(ascending=False).head(50)}")
# Out:
# Missing values:
# ngay_gio_re_put                 134887
# ghi_chu                         134887
# ma_so_vi_tri_actual              26472
# ngay_gio_bd_cham                 26431
# ngay_gio_kt_cham                 26428
# nv_cham_hang                     26419
# so_lpn                             111
# last_updated_by_function             0
# last_updated_by                      0
# last_updated                         0
# created_by_function                  0
# created_by                           0
# created                              0
# deleted                              0
# auto_id                              0
# chu_hang_id                          0
# trang_thai_id                        0
# sl_repleshniment_all_special         0
# sl_repleshniment_le                  0
# sl_repleshniment_chan                0
# so_kien_repleshniment                0
# ma_so_vi_tri_moi                     0
# ma_so_vi_tri_cu                      0
# ...

# %%
#kiểm tra cột data lưu ý thay đổi
cham["ma_so_vi_tri_actual"].value_counts(dropna=False)
# Out:
# ma_so_vi_tri_actual
# NaN                26472
# DV000001            1822
# DV000007            1139
# DV000008            1018
# DV000009             231
#                    ...
# r20-074-07             1
# R09-018-09             1
# r14-018-05             1
# 01-01-018-01-01        1
# R01-026-05             1
# Name: count, Length: 7891, dtype: int64

# %%
#drop những cột data missing value quá nhiều và không có giá trị
drop_colums_cham = ["ngay_gio_re_put", "ghi_chu"
]
cham = cham.drop(columns=drop_colums_cham)

# %%
# Xóa dòng trùng
cham = cham.drop_duplicates()

# %%
#tạo file csv clean
#cham.to_csv("../data/clean/log_cham_hang.csv", index=False)

# %% [markdown]
# ## Xuất kho

# %%
print(f"Shape: {xuatkho.shape}")
print(f"info: {xuatkho.info()}")
# Out:
# Shape: (1661161, 39)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1661161 entries, 0 to 1661160
# Data columns (total 39 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   auto_id                          1661161 non-null  int64
#  1   chu_hang_id                      1661161 non-null  int64
#  2   kho_id                           1661161 non-null  int64
#  3   xuat_kho_id                      1661161 non-null  int64
#  4   xuat_kho_raw_data_id             1661161 non-null  int64
#  5   vi_tri_id                        1661161 non-null  int64
#  6   ton_kho_id                       1661161 non-null  int64
#  7   nhap_kho_id                      1661161 non-null  int64
#  8   san_pham_id                      1661161 non-null  int64
#  9   so_po                            1542432 non-null  object
#  10  so_lot                           254 non-null      object
# ...

# %%
print(f"\nMissing values:\n{xuatkho.isnull().sum().sort_values(ascending=False).head(50)}")
# Out:
# Missing values:
# so_serial                          1661161
# ma_key_lo_hang                     1661161
# so_lot                             1660907
# so_batch                           1619074
# sl_ton_all_special_on_allocated    1575234
# sl_ton_le_on_allocated              605919
# sl_ton_chan_on_allocated            605919
# so_kien_ton_on_allocated            605919
# ngay_het_han                        396364
# ngay_san_xuat                       280090
# so_po                               118729
# so_lpn                                9341
# cbm                                      0
# deleted                                  0
# created                                  0
# created_by                               0
# nw                                       0
# gw                                       0
# created_by_function                      0
# don_gia_xuat                             0
# don_gia_nhap                             0
# ...

# %%
#drop những data dư thừa và không cần thiết và missing quá nhiều
drop_colums_xuat = ["created",
    "created_by",
    "created_by_function",
    "last_updated",
    "last_updated_by",
    "last_updated_by_function",
    "so_serial", "ma_key_lo_hang", "so_lot", "so_batch"]

xuatkho = xuatkho.drop(columns= drop_colums_xuat)

# %%
# Xóa dòng trùng
xuatkho = xuatkho.drop_duplicates()

# %%
#tạo file csv clean
# xuatkho.to_csv("../data/clean/xnk_xuat_kho_clean.csv", index=False)

# %% [markdown]
# ## Sản phẩm

# %%
print(f"Shape: {sanpham.shape}")
print(f"info: {sanpham.info()}")
# Out:
# Shape: (348338, 52)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348338 entries, 0 to 348337
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   auto_id                   348334 non-null  object
#  1   chu_hang_id               348335 non-null  object
#  2   nhom_nganh_hang_id        348333 non-null  float64
#  3   nganh_hang_id             348333 non-null  object
#  4   loai_san_pham_id          348332 non-null  object
#  5   don_vi_tinh_id            348331 non-null  float64
#  6   don_vi_tinh_thung_id      348327 non-null  object
#  7   ma_san_pham               348329 non-null  object
#  8   ma_sp_ncc                 16 non-null      object
#  9   ten_san_pham              348329 non-null  object
#  10  sl_cai_1_thung            348307 non-null  object
#  11  sl_thung_1_pallet         348305 non-null  object
#  12  qui_cach_thung_type_id    348305 non-null  object
# ...

# %%
print(f"\nMissing values:\n{sanpham.isnull().sum().sort_values(ascending=False).head(50)}")
# Out:
# Missing values:
# ma_sp_ncc                   348322
# barcode_item_5              348258
# barcode_item_4              348127
# ghi_chu                     348097
# barcode_item_3              347804
# barcode_thung_5             347452
# barcode_item_2              346585
# barcode_thung_4             345147
# barcode_thung_3             342333
# barcode_item_1              338217
# barcode_thung_2             330618
# barcode_thung_1               3412
# last_updated_by                 46
# last_updated_by_function        46
# last_updated                    45
# created                         44
# created_by                      44
# created_by_function             44
# deleted                         43
# san_pham_type_id                43
# co_che_fifo_id                  40
# gia_ban                         40
# carton_cao                      39
# trang_thai_id                   39
# so_ngay_su_dung                 39
# chien_luoc_pick_id              39
# ...

# %%
#xóa những cột không liên quan và không có giá trị
drop_colums = ["created",
    "created_by",
    "created_by_function",
    "last_updated",
    "last_updated_by",
    "last_updated_by_function",
    "deleted",
    "don_gia",
    "gia_mua",
    "gia_ban",
    "ma_sp_ncc",
    ]

sanpham = sanpham.drop(columns=drop_colums)

# %%
#chuẩn hóa mã sản phẩm và id về dạng số     
numeric_columns = [
"ma_san_pham",
"auto_id"
]

for col in numeric_columns:
    sanpham[col] = pd.to_numeric(sanpham[col], errors="coerce")

# %%
# Xóa các dòng có auto_id bị trống
sanpham = sanpham.dropna(subset=["auto_id"])

# Xóa các dòng có auto_id = 0
sanpham = sanpham[sanpham["auto_id"] != 0]

# %%
#xóa những sản phẩm không có mã sản phẩm
sanpham = sanpham.dropna(subset=["ma_san_pham"])
sanpham = sanpham[sanpham["ma_san_pham"] != 0]
# Xóa dòng trùng
sanpham = sanpham.drop_duplicates()

# %%
#chuẩn hóa cbm về dạng số để phân tích
sanpham["cbm_san_pham"] = pd.to_numeric(sanpham["cbm_san_pham"], errors="coerce")
sanpham["gw_san_pham"] = pd.to_numeric(sanpham["gw_san_pham"], errors="coerce")

# %%
#kiểm tra thể tích và cân nặng vì missing ở đây khá nhiều và là một yếu tố quan trọng
sanpham["cbm_san_pham"].describe()
# Out:
# count    3.483050e+05
# mean     2.516306e+03
# std      2.112192e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      4.660500e+06
# Name: cbm_san_pham, dtype: float64

# %%
sanpham["gw_san_pham"].describe()
# Out:
# count    348305.000000
# mean          0.596102
# std           4.265104
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        2008.000000
# Name: gw_san_pham, dtype: float64

# %%
#tạo file csv clean
#sanpham.to_csv("../data/clean/dm_san_pham_clean.csv", index=False)

# %% [markdown]
# ## Vị trí

# %%
print(f"Shape: {vitri.shape}")
print(f"info: {vitri.info()}")
# Out:
# Shape: (26870, 24)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26870 entries, 0 to 26869
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   auto_id                   26870 non-null  int64
#  1   kho_id                    26870 non-null  int64
#  2   day_ke_id                 26870 non-null  int64
#  3   ma_so_vi_tri              26870 non-null  object
#  4   tang                      26870 non-null  int64
#  5   dai                       26870 non-null  float64
#  6   rong                      26870 non-null  float64
#  7   cao                       26870 non-null  float64
#  8   vi_tri_type_id            26870 non-null  int64
#  9   vi_tri_seq_id             26870 non-null  int64
#  10  tag                       0 non-null      float64
#  11  sl_pallet                 26870 non-null  float64
#  12  sl_sku                    26870 non-null  float64
# ...

# %%
print(f"\nMissing values:\n{vitri.isnull().sum().sort_values(ascending=False).head(50)}")
# Out:
# Missing values:
# tag                         26870
# ghi_chu                     26848
# auto_id                         0
# gw_max                          0
# last_updated_by                 0
# last_updated                    0
# created_by_function             0
# created_by                      0
# created                         0
# deleted                         0
# trang_thai_id                   0
# cbm_max                         0
# sl_sku                          0
# kho_id                          0
# sl_pallet                       0
# vi_tri_seq_id                   0
# vi_tri_type_id                  0
# cao                             0
# rong                            0
# dai                             0
# tang                            0
# ma_so_vi_tri                    0
# day_ke_id                       0
# last_updated_by_function        0
# dtype: int64

# %%
#drop những hàng và cột data không cần thiết và missing value quá nhiều
drop_colums = ["created",
    "created_by",
    "created_by_function",
    "last_updated",
    "last_updated_by",
    "last_updated_by_function",
    "deleted"]
vitri = vitri.drop(columns=drop_colums)

# %%
# Xóa dòng trùng
vitri = vitri.drop_duplicates()

# %%
#kiểm tra có bao nhiêu loại tầng
vitri["tang"].nunique()
# Out:
# 11

# %%
#những tầng thực tế cụ thể
vitri["tang"].unique()
# Out:
# array([ 3,  4,  2,  1,  0,  5,  6,  9, 10,  7,  8], dtype=int64)

# %%
#số lượng vị trí các tầng có đầy đủ thông số dài, rộng, cao
vitri.groupby("tang")[["dai", "rong", "cao"]].apply(
    lambda x: x.notna().all(axis=1).sum()
)
# Out:
# tang
# 0      968
# 1     4846
# 2     3930
# 3     3765
# 4     3690
# 5     2797
# 6     1666
# 7     1302
# 8     1302
# 9     1302
# 10    1302
# dtype: int64

# %%
#chuyển 0 thành NaN để không ảnh hưởng đến tính gtri trung bình
for col in ["dai", "rong", "cao"]:
    vitri[col] = vitri[col].replace(0, np.nan)
#tính trung bình
for col in ["dai", "rong", "cao"]:
    vitri[col] = vitri[col].mask(
        vitri[col] == 0,
        vitri.groupby("tang")[col].transform("mean")
    )

# Điền chiều dài theo trung bình của cùng tầng
vitri["dai"] = vitri["dai"].fillna(
    vitri.groupby("tang")["dai"].transform("mean")
)

# Điền chiều rộng
vitri["rong"] = vitri["rong"].fillna(
    vitri.groupby("tang")["rong"].transform("mean")
)

# Điền chiều cao
vitri["cao"] = vitri["cao"].fillna(
    vitri.groupby("tang")["cao"].transform("mean")
)

# %%
#lấy cbm max của các tầng 7,8,9,10 
vitri[vitri["tang"].isin([7, 8, 9, 10])] \
    .groupby("tang")["cbm_max"] \
    .unique()
# Out:
# tang
# 7     [1860000.0, 1782500.0]
# 8     [1860000.0, 1782500.0]
# 9     [1860000.0, 1782500.0]
# 10    [1860000.0, 1782500.0]
# Name: cbm_max, dtype: object

# %%
vitri[
    vitri["cbm_max"].isin([1782500, 1860000])
].groupby("tang")["cbm_max"].unique()
# Out:
# tang
# 0                [1860000.0]
# 1     [1782500.0, 1860000.0]
# 4     [1860000.0, 1782500.0]
# 5     [1860000.0, 1782500.0]
# 6     [1860000.0, 1782500.0]
# 7     [1860000.0, 1782500.0]
# 8     [1860000.0, 1782500.0]
# 9     [1860000.0, 1782500.0]
# 10    [1860000.0, 1782500.0]
# Name: cbm_max, dtype: object

# %%
cols = ["dai", "rong", "cao"]

# Chuyển 0 thành NaN để không ảnh hưởng khi tính trung bình
vitri[cols] = vitri[cols].replace(0, np.nan)

# Điền theo cbm_max
for col in cols:
    vitri[col] = vitri[col].fillna(
        vitri.groupby("cbm_max")[col].transform("mean")
    )

# %%
# Đổi 0 thành NaN để không ảnh hưởng đến trung bình
vitri["cbm_max"] = vitri["cbm_max"].replace(0, np.nan)

# Điền cbm_max theo trung bình của cùng tầng
vitri["cbm_max"] = vitri["cbm_max"].fillna(
    vitri.groupby("tang")["cbm_max"].transform("mean")
)

# %%
#tạo file csv clean
#vitri.to_csv("../data/clean/dm_vi_tri_clean.csv", index=False)
